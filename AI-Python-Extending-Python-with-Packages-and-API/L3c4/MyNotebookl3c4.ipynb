# %% [markdown]
# # Lesson 3: Using third-party packages

# %% [markdown]
# In this lesson, you'll try out some third-party Python packages that let you explore and visualize data!

# %% [markdown]
# ## Loading and exploring data with ```pandas```

# %% [markdown]
# One of the most popular Python third-party packages is called ```pandas```.
#
# It helps you with loading and exploring structured data, like the kind stored in spreadsheets and ```.csv``` files. Check out the [Pandas documentation](https://pandas.pydata.org/) if you want to learn more!
#
# To use the ```pandas``` package, you first need to load it:

# %%
import pandas as pd

# %% [markdown]
# <p style="background-color:#F5C780; padding:15px"> 🤖 <b>Use the Chatbot</b>:
# <br><br>
# What does "as" in the following code do?<br><br>
# import pandas as pd
# </p>

# %% [markdown]
# RESPONSE CHATBOT : The line import pandas as pd in Python is an import statement that brings the Pandas library into the script and assigns it the alias pd.
#
# Here's a breakdown:
#
# import pandas: This imports the Pandas library, a powerful and widely used Python package for data manipulation and analysis.
#
# as pd: This part creates an alias, meaning you can refer to the pandas library using the shorter name pd throughout your code. This is a common convention in the Python community to make the code more concise and readable.
#
# Once Pandas is imported as pd, you can use it to perform tasks like:
#
# Reading and writing data from various file formats (CSV, Excel, SQL databases, etc.)
# Manipulating data using DataFrames (2D data structures) and Series (1D data structures)
# Performing data cleaning, transformation, and analysis tasks
# Working with time-series data
# For example, after importing pandas as pd, you can load a CSV file into a DataFrame like this:
#
# df = pd.read_csv('data.csv')

# %% [markdown]
# So `import pandas as pd` creates a shortcut that you can use to avoid typing pandas.
#
# **Note:** you'll need to use the `.` notation when using the function in pandas - go back to the "Using functions from a local file" lesson in this course if you need a refresher!

# %% [markdown]
# Next, you'll load a CSV file of used car sales prices using pandas:

# %%
# Dataset adapted from here https://www.kaggle.com/datasets/nehalbirla/vehicle-dataset-from-cardekho
data = pd.read_csv('car_data.csv')

print(data)
# Out:
#                          Model    Price  Year  Kilometer
# 0    Honda Amaze 1.2 VX i-VTEC  5050.00  2017      87150
# 1              Honda Brio V MT  3510.00  2014      39276
# 2      Honda WR-V VX MT Petrol  8199.99  2018      27963
# 3            Honda CR-V 2.4 AT  8600.00  2013      67000
# 4              Honda Brio S MT  4400.00  2016      50374
# ..                         ...      ...   ...        ...
# 153  Honda Accord 2.4 iVtec AT  1950.00  2008      57885
# 154       Honda City SV Diesel  7500.00  2018      75000
# 155               Honda City V  7300.00  2016      51834
# 156          Honda City SV CVT  5900.00  2015     116592
# 157               Honda City V  4800.00  2015      49000
#
# [158 rows x 4 columns]

# %% [markdown]
# How do you show only cars that sold for more than $10,000? Let's ask the chatbot!

# %% [markdown]
# <p style="background-color:#F5C780; padding:15px"> 🤖 <b>Use the Chatbot</b>:
# <br><br>
# I have loaded some data using this code:
# <br><br>data = pd.read_csv('car_data.csv')
# <br>print(data)<br><br>
# The data looks like this when I print it: <br>
# Model    Price  Year  Kilometer <br>
# 0    Honda Amaze 1.2 VX i-VTEC  5050.00  2017      87150 <br>
# 1              Honda Brio V MT  3510.00  2014      39276 <br>
# 2      Honda WR-V VX MT Petrol  8199.99  2018      27963 <br>
# 3            Honda CR-V 2.4 AT  8600.00  2013      67000 <br>
# 4              Honda Brio S MT  4400.00  2016      50374 <br><br>
# Show only the cars with a price greater than or equal to 10000. <br>
# </p>

# %% [markdown]
# RESPONSE CHATBOT
# Here is the snippet code to filter cars with a price greater than or equal to 10,000:
# # Filter the data for cars with a price greater than or equal to 10,000
# filtered_data = data[data['Price'] >= 10000]
#
# # Display the filtered data
# print(filtered_data)

# %% [markdown]
# Next, run the code the LLM wrote to filter the data by price:

# %%
# Code to show only the cars with a price >= 10000
print(data[data["Price"]>=10000])
# Out:
#                                     Model    Price  Year  Kilometer
# 21                           Honda City V  10600.0  2019      12382
# 30               Honda City ZX CVT Petrol  17000.0  2022       8530
# 38               Honda City ZX CVT Petrol  14500.0  2021      13000
# 41               Honda City VX CVT Petrol  13900.0  2022      32000
# 56   Honda City ZX CVT Petrol [2017-2019]  11380.0  2018       6000
# 63                   Honda City ZX Diesel  14900.0  2021      11000
# 76   Honda City VX CVT Petrol [2017-2019]  10500.0  2017      29386
# 78               Honda City ZX CVT Petrol  15300.0  2022       2000
# 79                    Honda City V Petrol  10950.0  2022       2700
# 88    Honda City V CVT Petrol [2017-2019]  13400.0  2021      11000
# 109                         Honda City VX  11990.0  2020      26497
# 117                  Honda City ZX Diesel  14500.0  2022       2500
# 121                         Honda City VX  12550.0  2021      10000
# 134   Honda City V CVT Petrol [2017-2019]  10400.0  2019      18000
# 143                Honda CR-V 2.0L 2WD AT  11300.0  2015      50000

# %%
# Code to show only the cars with a price =< 10000
print(data[data["Price"] <= 10000])
# Out:
#                          Model    Price  Year  Kilometer
# 0    Honda Amaze 1.2 VX i-VTEC  5050.00  2017      87150
# 1              Honda Brio V MT  3510.00  2014      39276
# 2      Honda WR-V VX MT Petrol  8199.99  2018      27963
# 3            Honda CR-V 2.4 AT  8600.00  2013      67000
# 4              Honda Brio S MT  4400.00  2016      50374
# ..                         ...      ...   ...        ...
# 153  Honda Accord 2.4 iVtec AT  1950.00  2008      57885
# 154       Honda City SV Diesel  7500.00  2018      75000
# 155               Honda City V  7300.00  2016      51834
# 156          Honda City SV CVT  5900.00  2015     116592
# 157               Honda City V  4800.00  2015      49000
#
# [143 rows x 4 columns]

# %% [markdown]
# You can also filter by other columns in the data, for example the year:

# %%
# Show all the cars from the 2015 
print(data[data["Year"]==2015])
# Out:
#                            Model    Price  Year  Kilometer
# 20        Honda Mobilio S Diesel   4750.0  2015      72000
# 24        Honda Jazz V AT Petrol   5450.0  2015      42000
# 32          Honda Jazz SV Petrol   4950.0  2015      52000
# 36           Honda City S Diesel   6450.0  2015      64000
# 40           Honda City V Diesel   5250.0  2015     114635
# 54          Honda City VX (O) MT   5950.0  2015      72000
# 73                 Honda City VX   5500.0  2015      44000
# 93           Honda City S Diesel   5850.0  2015      61000
# 96       Honda Mobilio RS Diesel   6750.0  2015      48000
# 98          Honda City SV Diesel   5400.0  2015      76000
# 101            Honda City SV CVT   5900.0  2015      75258
# 103          Honda Jazz V Diesel   5250.0  2015      68244
# 123            Honda City VX CVT   6900.0  2015      59000
# 125    Honda Amaze 1.5 VX i-DTEC   5150.0  2015      63587
# 135  Honda Jazz S AT [2015-2016]   5200.0  2015      42000
# 143       Honda CR-V 2.0L 2WD AT  11300.0  2015      50000
# 156            Honda City SV CVT   5900.0  2015     116592
# 157                 Honda City V   4800.0  2015      49000

# %% [markdown]
# Pandas includes built-in tools to calculate interesting statistics, like the median selling value for the cars from 2015. Here's the code:

# %%
filtered_data = data[data["Year"]==2015]
print(filtered_data["Price"].median())
print(f"The median of the cars built up in 2015 is {filtered_data["Price"].median()}")
# Out:
# 5475.0
# The median of the cars built up in 2015 is 5475.0

# %% [markdown]
# ## Plotting data with ```matplotlib```

# %% [markdown]
# This is a popular package used by data scientists and developers to visualize data. You can check out the [Matplotlib documentation](https://matplotlib.org/) if you want to learn more!
#
# To use matplotlib, you first have to import it with the following command:

# %%
# Note the .pyplot
import matplotlib.pyplot as plt

# %% [markdown]
# Don't worry about remembering this command, you can always find it by asking a chatbot or searching online. Again, the `as` form of the import command is being used to set up an alias - so now you can type `plt` instead of `matplotlib.pyplot` saving you lots of typing!
#
# Let's start by using ```matplotlib.pyplot``` to plot the selling price of a car against how many miles it has driven:

# %%
plt.scatter(data["Kilometer"], data["Price"])

plt.title('Car Price vs. Kilometers Driven')
plt.xlabel('Kilometers Driven')
plt.ylabel('Price (in USD)')

plt.show()

# %% [markdown]
# Matplotlib has many settings that can help you customize your charts. You can ask a chatbot to help you write the code to modify these settings:

# %% [markdown]
# <p style="background-color:#F5C780; padding:15px"> 🤖 <b>Use the Chatbot</b>:
# <br><br>
# I have the following plot in matplotlib:
# <br><br>
# plt.scatter(data["Kilometer"], data["Price"])
# <br>plt.title('Car Price vs. Kilometers Driven')<br>
# plt.xlabel('Kilometers Driven')<br>
# plt.ylabel('Price (in USD)')<br>
# plt.show()<br><br>
# Please add a grid, change the scatter plot color to red, and increase the title font size.
# </p>

# %% [markdown]
# RESPONSE CHATBOT :
# import matplotlib.pyplot as plt
#
# # Scatter plot with a grid, red color, and increased title font size
# plt.scatter(data["Kilometer"], data["Price"], color='red')  # Change scatter plot color to red
# plt.title('Car Price vs. Kilometers Driven', fontsize=16)  # Increase title font size
# plt.xlabel('Kilometers Driven')
# plt.ylabel('Price (in USD)')
# plt.grid(True)  # Add grid
# plt.show()

# %% [markdown]
# Let's try the code the chatbot suggested:

# %%
plt.scatter(data["Kilometer"], data["Price"], color='red')
plt.title('Car Price vs. Kilometers Driven', fontsize=16)
plt.xlabel('Kilometers Driven')
plt.ylabel('Price (in USD)')

# Add the grid
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# ## Extra practice
#
# Use the 🤖 chatbot to help you try the following exercises!
#
# ### Exercise 1
#
# Write code to create a filtered table of all the Honda Accords in the dataset.
#
# **Hint:** You can always copy and paste the code from the earlier parts of this notebook and ask the chatbot to modify it!

# %%
# Get the unique car models in the dataset
unique_models = data['Model'].unique()

# Display the unique models
print("Car Models Overview:")
for model in unique_models:
    print(model)
# Out:
# Car Models Overview:
# Honda Amaze 1.2 VX i-VTEC
# Honda Brio V MT
# Honda WR-V VX MT Petrol
# Honda CR-V 2.4 AT
# Honda Brio S MT
# Honda City V Petrol [2017-2019]
# Honda Civic 1.8S MT
# Honda City V CVT Petrol [2017-2019]
# Honda Jazz VX Petrol
# Honda Amaze 1.5 SX i-DTEC
# Honda Amaze 1.2 SX i-VTEC
# Honda City 1.5 S MT
# Honda City V
# Honda City VX (O) MT
# Honda City 1.5 S AT
# Honda Brio EX MT
# Honda Amaze VX CVT 1.2 Petrol
# Honda Mobilio S Diesel
# Honda Amaze 1.5 S i-DTEC
# Honda Jazz V AT Petrol
# Honda Jazz S
# Honda WR-V S MT Petrol
# Honda City ZX CVT Petrol
# Honda City E [2013-2016]
# Honda Jazz SV Petrol
# Honda Amaze 1.2 VX AT i-VTEC
# Honda City SV Diesel
# Honda City S Diesel
# Honda City SV
# Honda City V Diesel
# Honda City VX CVT Petrol
# Honda Amaze 1.2 S i-VTEC
# Honda Jazz V Petrol
# Honda City 1.5 V MT
# Honda City E Diesel
# Honda Amaze 1.2 V CVT Petrol [2018-2020]
# Honda Amaze 1.2 S MT Petrol [2018-2020]
# Honda City ZX CVT Petrol [2017-2019]
# Honda Amaze 1.5 VX CVT Diesel
# Honda Brio E MT
# Honda City VX CVT
# Honda City ZX Diesel
# Honda City 1.5 EXi
# Honda Amaze 1.2 S i-VTEC Opt
# Honda City 1.5 V AT
# Honda City VX
# Honda City VX CVT Petrol [2017-2019]
# Honda City V Petrol
# Honda City S Petrol
# Honda Civic 1.8V MT
# Honda Amaze 1.5 VX i-DTEC
# Honda City VX (O) MT BL
# Honda Amaze 1.2 S CVT Petrol [2018-2020]
# Honda Mobilio RS Diesel
# Honda WR-V S MT Diesel
# Honda City SV CVT
# Honda Jazz V Diesel
# Honda Amaze 1.5 E i-DTEC
# Honda Amaze 1.2 VX MT Petrol [2018-2020]
# Honda Amaze 1.2 E MT Petrol [2018-2020]
# Honda Accord 2.4 AT
# Honda Amaze 1.2 S AT i-VTEC
# Honda Amaze 1.2 E i-VTEC
# Honda Jazz VX CVT Petrol
# Honda Jazz S AT [2015-2016]
# Honda City VX Petrol [2017-2019]
# Honda BR-V V CVT Petrol
# Honda CR-V 2.0L 2WD AT
# Honda WR-V VX MT Diesel
# Honda City CVT
# Honda Brio VX AT
# Honda City 1.5 E MT
# Honda Accord 2.4 iVtec AT

# %%
# WRITE YOUR CODE HERE
# Show all the cars from the 2015 
print(data[data["Model"]=="Honda Accord 2.4 iVtec AT"])
# Out:
#                          Model   Price  Year  Kilometer
# 153  Honda Accord 2.4 iVtec AT  1950.0  2008      57885

# %% [markdown]
# ### Exercise 2
#
# Write code to display a scatter plot of sales price vs year.

# %%
import pandas as pd

# %%
data = pd.read_csv('car_data.csv')

print(data)
# Out:
#                          Model    Price  Year  Kilometer
# 0    Honda Amaze 1.2 VX i-VTEC  5050.00  2017      87150
# 1              Honda Brio V MT  3510.00  2014      39276
# 2      Honda WR-V VX MT Petrol  8199.99  2018      27963
# 3            Honda CR-V 2.4 AT  8600.00  2013      67000
# 4              Honda Brio S MT  4400.00  2016      50374
# ..                         ...      ...   ...        ...
# 153  Honda Accord 2.4 iVtec AT  1950.00  2008      57885
# 154       Honda City SV Diesel  7500.00  2018      75000
# 155               Honda City V  7300.00  2016      51834
# 156          Honda City SV CVT  5900.00  2015     116592
# 157               Honda City V  4800.00  2015      49000
#
# [158 rows x 4 columns]

# %%
# WRITE YOUR CODE HERE
import matplotlib.pyplot as plt

# Scatter plot with a grid, red color, and increased title font size
plt.scatter(data["Price"], data["Year"], color='red')  # Change scatter plot color to red
plt.title('Car Sales Price vs. Years', fontsize=16)  # Increase title font size
plt.xlabel('Price (in USD)')
plt.ylabel('Year')
plt.grid(True)  # Add grid
plt.show()

# %% [markdown]
# ### Challenge exercise!
#
# Ask the LLM to help you create a pie chart of the data showing how many cars were sold each year.
#
# **Hint:** Be sure you tell the chatbot what your data variable is called! It may pick a different name by default.

# %%
import matplotlib.pyplot as plt

# Count the number of cars per year
year_counts = data['Year'].value_counts()

# Increase the size of the pie chart
plt.figure(figsize=(12,12)) #Adjust the figure size (width, height)

# Plot the pie chart
plt.pie(year_counts, labels=year_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Cars Sold per Year')
plt.show()

# %% [markdown]
# CHALLENGE
# HAVE A LOOK AT THE DATASET BOX_OFFICE

# %%
import pandas as pd

# %%
# Load the data from CSV
data = pd.read_csv('box_office.csv')
print(data)
# Out:
#                             Brand        Total  \
# 0                   Marvel Comics  15806336901
# 1              Legendary Pictures   7018798067
# 2                       Lucasfilm   6325022918
# 3                           Pixar   6078217662
# 4                       DC Comics   5815645953
# 5            DreamWorks Animation   5792217737
# 6           Vertigo Entertainment   3154664176
# 7                       Bad Robot   3077078931
# 8   Walt Disney Animation Studios   2774912904
# 9      Illumination Entertainment   2759505881
# 10          Blumhouse Productions   2451844676
# 11                         Hasbro   2079485824
# 12                    Nickelodeon   1930746182
# 13        Sony Pictures Animation   1918763863
# 14                   Walden Media   1842852183
# 15                       Blue Sky   1740428763
# 16                   Stephen King   1729648950
# 17                            MTV   1520456359
# 18                 Platinum Dunes   1422911399
#
#                                            #1 Release
# 0                                   Avengers: Endgame
# 1                                      Jurassic World
# 2          Star Wars: Episode VII - The Force Awakens
# 3                                       Incredibles 2
# 4                                     The Dark Knight
# 5                                             Shrek 2
# 6                                                  It
# 7          Star Wars: Episode VII - The Force Awakens
# 8                                           Frozen II
# 9                             The Secret Life of Pets
# 10                                            Get Out
# 11                Transformers: Revenge of the Fallen
# 12                       Teenage Mutant Ninja Turtles
# 13                  Spider-Man: Into the Spider-Verse
# 14  The Chronicles of Narnia: The Lion the Witch a...
# 15                   Ice Age 3: Dawn of the Dinosaurs
# 16                                                 It
# 17                                   The Longest Yard
# 18                       Teenage Mutant Ninja Turtles

# %%
#Since the csv dataset seems to cantain a lot of items, let's have a quick look first at few rows of the data
print("\nFirst 5 Rows of the Data:")
print(data.head())
# Out:
# First 5 Rows of the Data:
#                 Brand        Total                                  #1 Release
# 0       Marvel Comics  15806336901                           Avengers: Endgame
# 1  Legendary Pictures   7018798067                              Jurassic World
# 2           Lucasfilm   6325022918  Star Wars: Episode VII - The Force Awakens
# 3               Pixar   6078217662                               Incredibles 2
# 4           DC Comics   5815645953                             The Dark Knight

# %%
# 1. Overview of the columns (variables)
print("Column Names:")
print(data.columns)
# Out:
# Column Names:
# Index(['Brand', 'Total', '#1 Release'], dtype='object')

# %%
# Data types of each column
print("\nData Types:")
print(data.dtypes)
# Out:
# Data Types:
# Brand         object
# Total          int64
# #1 Release    object
# dtype: object

# %%
# Summary statistics of the numeric columns
print("\nSummary Statistics:")
print(data.describe())
# Out:
# Summary Statistics:
#               Total
# count  1.900000e+01
# mean   3.959976e+09
# std    3.429554e+09
# min    1.422911e+09
# 25%    1.880808e+09
# 50%    2.759506e+09
# 75%    5.803932e+09
# max    1.580634e+10
